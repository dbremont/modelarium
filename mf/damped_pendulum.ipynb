# %% [markdown]
# # A Case Study of a Dissipative System: Damped Pendulum

# %% [markdown]
# ## Formulation

# %% [markdown]
# $\frac{d^2\theta}{dt^2} + \gamma \frac{d\theta}{dt} + \frac{g}{L} \sin(\theta) = 0$

# %% [markdown]
# ## Implementation

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp

# %%
# Parameters
g = 9.81      # gravitational acceleration (m/s^2)
L = 1.0       # length of pendulum (m)
gamma = 0.5   # damping coefficient

# Differential equation system
def damped_pendulum(t, y):
    theta, omega = y
    dtheta_dt = omega
    domega_dt = -gamma * omega - (g / L) * np.sin(theta)
    return [dtheta_dt, domega_dt]

# Initial conditions
theta0 = np.pi / 3  # 60 degrees
omega0 = 0.0        # initial angular velocity
y0 = [theta0, omega0]

# Time span
t_span = (0, 10)
t_eval = np.linspace(*t_span, 1000)

# Solve ODE
sol = solve_ivp(damped_pendulum, t_span, y0, t_eval=t_eval)

# %%
# Plotting
plt.figure(figsize=(10, 5))
plt.plot(sol.t, sol.y[0], label=r'$\theta(t)$ (angle)')
plt.plot(sol.t, sol.y[1], label=r'$\omega(t)$ (angular velocity)', linestyle='--')
plt.title('Damped Nonlinear Pendulum')
plt.xlabel('Time (s)')
plt.ylabel('Value')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ## References

# %% [markdown]
# - [A Case Study of a Dissipative System: Damped Pendulum](https://righteous-guardian-68f.notion.site/A-Case-Study-of-a-Dissipative-System-Damped-Pendulum-1ebc0f5171ec80c09a6af45b6f968c2b?pvs=4)
