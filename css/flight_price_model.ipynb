# %% [markdown]
# # Flight Price Prediction

# %% [markdown]
# > ...

# %% [markdown]
# ## Set Up

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
SRC='/home/dvictoriano/Downloads/data/flight_price.csv'

# %%
dset  = pd.read_csv(SRC)

# %%
dset
# Out:
#         Unnamed: 0   airline   flight source_city departure_time stops  \
# 0                0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1                1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2                2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3                3   Vistara   UK-995       Delhi        Morning  zero
# 4                4   Vistara   UK-963       Delhi        Morning  zero
# ...            ...       ...      ...         ...            ...   ...
# 300148      300148   Vistara   UK-822     Chennai        Morning   one
# 300149      300149   Vistara   UK-826     Chennai      Afternoon   one
# 300150      300150   Vistara   UK-832     Chennai  Early_Morning   one
# 300151      300151   Vistara   UK-828     Chennai  Early_Morning   one
# 300152      300152   Vistara   UK-822     Chennai        Morning   one
#
#          arrival_time destination_city     class  duration  days_left  price
# ...

# %% [markdown]
# ##  Pre-Processing

# %% [markdown]
# ## Visualization

# %% [markdown]
# Plan:
#
# - Data Distribution
# - Time Series  Analysis: Prices
# - Correlation:
#     - Heatmap
#     - Plot  / Regression
# - Multicollinearity

# %%
# # Set up a grid for subplots
# fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(15, 15))

# # Flatten the axes array for easier indexing
# axes = axes.flatten()

# # List of features to visualize
# columns = ['price', 'duration', 'stops', 'airline', 'source_city', 'destination_city', 'departure_time', 'arrival_time']
# # palette = sns.color_palette("husl", n_colors=len(dset[feature].unique()))  # 'husl' is an example palette
# # sns.set_palette("Set2")

# # Plot the distributions of the features
# for i, col in enumerate(columns):
#     ax = axes[i]
    
#     # Check if the feature is numerical or categorical
#     if dset[col].dtype == 'object':
#         # Categorical variable: plot a countplot or barplot
#         # sns.countplot(x=dset[feature], ax=ax, hue='Category',  palette=sns.color_palette("viridis"), legend=False, data = dset)
#         # sns.countplot(x=dset[feature], ax=ax, hue=col,  palette=sns.color_palette("viridis"), legend=False, data = dset)
#         sns.countplot(x=dset[feature], ax=ax)
#         ax.set_title(f'Distribution of {col}')
#         ax.set_xlabel(col)
#         ax.set_ylabel('Count')
#     else:
#         # Numerical variable: plot a histogram
#         sns.histplot(dset[col], ax=ax, kde=True, color='skyblue', edgecolor='black')
#         ax.set_title(f'Distribution of {col}')
#         ax.set_xlabel(col)
#         ax.set_ylabel('Frequency')

# # Adjust layout
# plt.tight_layout()
# plt.show()

# %%
# Set the aesthetic style of the plots
sns.set_theme(style="whitegrid")

# Create the subplots
fig, axs = plt.subplots(ncols=7, nrows=2, figsize=(20, 10))
axs = axs.flatten()

# Loop through the dataset and create plots
for index, (k, v) in enumerate(dset.items()):
    sns.histplot(v, kde=True, ax=axs[index])  # kde=True adds a Kernel Density Estimate plot

# Adjust the layout
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=5.0)

# %%
# Convert stops to a consistent format
df['Total_Stops'] = df['Total_Stops'].replace('non-stop', '0 stops')
stop_order = sorted(df['Total_Stops'].unique())

plt.figure(figsize=(8,6))
data = [df[df['Total_Stops'] == stop]['Price'] for stop in stop_order]
plt.boxplot(data, labels=stop_order)
plt.title("Price Distribution by Total Stops")
plt.xlabel("Total Stops")
plt.ylabel("Price (INR)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## References

# %% [markdown]
# - [Flight Price Prediction](https://www.kaggle.com/datasets/shubhambathwal/flight-price-prediction?resource=download)
# - [Visualization](https://righteous-guardian-68f.notion.site/Visualization-1afc0f5171ec8040896ce4c49f04f396?pvs=74)
